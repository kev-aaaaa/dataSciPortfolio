# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science tools and the ecosystem are summarized.

# %% [markdown]
# **Objectives**
# - List down popular Data Science languages
# - Enumerate popular open-source Data Science tools for various purposes within the ecosystem
# - Demonstrate examples of simple arithmetic with the Python language

# %% [markdown]
# ##  Author
#     Kevyn Andersen

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. C++
# 3. Julia
# 4. JavaScript
# 5. Scala

# %% [markdown]
# Some of the commonly used libraries by Data Scientists use are:
# 1. Pandas - for data structuring and tool versatility
# 2. NumPy - uses arrays and matrices
# 3. Matplotlib - most popular data visualization library
# 4. Seaborn - plots heat maps, time series, and violin plots

# %% [markdown]
# | Data Science Tools | Classification | Description |
# |--------------------|----------------|-------------|
# | Apache Hadoop | Data management | Allows efficient large-scale processing and analysis of big datasets|
# | Jupyter | Operating system | Allows the creation of Notebooks, and Lab, allowing collaborations between developers|
# |Kibana | Data visualization | Web-based interactive interface for large dataset analysis|
# |Kubernetes| Model Deployment | Automatically orchestrates machine learning models, providing management options|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic in Python

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This code converts minutes into hours by dividing by 60.
minutes = 200
hours = (minutes) / 60
print(hours)
# Out:
# 3.3333333333333335
